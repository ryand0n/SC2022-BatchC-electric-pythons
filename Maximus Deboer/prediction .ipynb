# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleaned_data')

# %%
def findfillerdata(state, title, race, gender, company, education, yearsofexperience):
    top_15_data = None
    if company in top_15:
        top_15_data = True
    else:
        top_15_data = False
    
    experience = convert(yearsofexperience)
    fillerdata = filler2[(filler2['state'] == state) & 
                     (filler2['title'] == title) & 
                     (filler2['race'] == race) & 
                     (filler2['gender'] == gender) & 
                     (filler2['in_top_15'] == top_15_data) & 
                     (filler2['education'] == education) & 
                     (filler2['experience'] == experience)]
    if len(fillerdata) == 0:
        return 'sorry no data found'
    else:
        return fillerdata

# %%
userinput = ['state', 'title', 'race', 'gender', 'experience', 'education', 'in_top_15']
filler2 = df.groupby(by = userinput)['yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus'].mean()
filler2.reset_index(inplace = True)
filler2.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 userinput = ['state', 'title', 'race', 'gender', 'experience', 'education', 'in_top_15']
# ----> 2 filler2 = df.groupby(by = userinput)['yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus'].mean()
#       3 filler2.reset_index(inplace = True)
#       4 filler2.head()
#
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
# ...

# %%
top_15 = list(df['company'].value_counts().head(15).index)
top_15
# Out:
# ['Amazon',
#  'Microsoft',
#  'Google',
#  'Facebook',
#  'Apple',
#  'Oracle',
#  'IBM',
#  'Intel',
#  'Cisco',
#  'Salesforce',
#  'Capital One',
#  'VMware',
#  'JPMorgan Chase',
#  'Deloitte',
#  'Uber']
