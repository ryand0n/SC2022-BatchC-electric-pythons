# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleaned_data')
df.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#      company              title  totalyearlycompensation  yearsofexperience  \
# 0     Google  Software Engineer                   400000                5.0
# 1  Microsoft  Software Engineer                   136000                3.0
# 2     Google  Software Engineer                   337000                6.0
# 3  Microsoft  Software Engineer                   222000                4.0
# 4      Blend  Software Engineer                   187000                5.0
#
#    yearsatcompany  basesalary  stockgrantvalue    bonus gender  \
# 0             5.0    210000.0         145000.0  45000.0   Male
# 1             2.0    124000.0           1000.0  11000.0   Male
# 2             6.0    177000.0         125000.0  36000.0   Male
# 3             4.0    164000.0          38000.0  20000.0   Male
# 4             0.0    165000.0          22000.0      0.0   Male
#
#    Masters_Degree  ...  Some_College  Race_Asian  Race_White  \
# 0               0  ...             0           1           0
# 1               0  ...             0           0           0
# 2               0  ...             0           1           0
# 3               1  ...             0           1           0
# 4               0  ...             0           0           1
#
#    Race_Two_Or_More  Race_Black  Race_Hispanic  state  in_top_15  education  \
# 0                 0           0              0     CA       True        PHD
# 1                 1           0              0     WA       True  Bachelors
# 2                 0           0              0     CA       True  Bachelors
# 3                 0           0              0     WA       True    Masters
# 4                 0           0              0     CA      False  Bachelors
#
#     race
# 0  Asian
# 1    Two
# 2  Asian
# 3  Asian
# 4  White
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['company', 'title', 'totalyearlycompensation', 'yearsofexperience',
#        'yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus', 'gender',
#        'Masters_Degree', 'Bachelors_Degree', 'Doctorate_Degree', 'Highschool',
#        'Some_College', 'Race_Asian', 'Race_White', 'Race_Two_Or_More',
#        'Race_Black', 'Race_Hispanic', 'state', 'in_top_15', 'education',
#        'race', 'experience'],
#       dtype='object')

# %%
#state, title, race, education, company, gender, experience

# %%
input = ['state', 'title', 'race', 'gender', 'experience', 'education', 'in_top_15']
filler = df.groupby(by = input)['yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus'].mean()
filler.reset_index(inplace = True)
filler
# Out:
# /tmp/ipykernel_4661/3881464316.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   filler = df.groupby(by = input)['yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus'].mean()
#      state                      title   race  gender          experience  \
# 0       CA           Business Analyst  Asian  Female   LITTLE EXPERIENCE
# 1       CA           Business Analyst  Asian  Female   LITTLE EXPERIENCE
# 2       CA           Business Analyst  Asian  Female   LITTLE EXPERIENCE
# 3       CA           Business Analyst  Asian  Female  Medium Experienced
# 4       CA           Business Analyst  Asian  Female  Medium Experienced
# ...    ...                        ...    ...     ...                 ...
# 3382    WA  Technical Program Manager  White    Male    Very Experienced
# 3383    WA  Technical Program Manager  White    Male    Very Experienced
# 3384    WA  Technical Program Manager  White    Male    Very Experienced
# 3385    WA  Technical Program Manager  White    Male    Very Experienced
# 3386    WA  Technical Program Manager  White   Other    Very Experienced
#
#       education  in_top_15  yearsatcompany     basesalary  stockgrantvalue  \
# 0     Bachelors      False        0.800000   98000.000000     10600.000000
# 1     Bachelors       True        1.666667   87333.333333      1000.000000
# 2       Masters      False        1.200000  102000.000000      8400.000000
# 3     Bachelors      False        0.500000  130000.000000      5000.000000
# 4     Bachelors       True        1.000000  140000.000000     31000.000000
# ...         ...        ...             ...            ...              ...
# 3382    Masters      False        8.428571  162571.428571      5714.285714
# 3383    Masters       True        5.142857  182571.428571     53785.714286
# 3384        PHD       True        7.000000  185000.000000    232500.000000
# 3385       Some       True        2.000000  206000.000000     36750.000000
# 3386  Bachelors      False        4.000000  140000.000000     15000.000000
#
#              bonus
# 0     10600.000000
# 1      8333.333333
# 2     19600.000000
# 3      5000.000000
# 4     21000.000000
# ...            ...
# 3382  16857.142857
# 3383  33857.142857
# 3384  20000.000000
# 3385  35250.000000
# 3386  35000.000000
#
# [3387 rows x 11 columns]

# %%
[(filler['state'] == 'CA') & (filler['title'] == 'Business Analyst') & (filler['race'] == 'Asian') & (filler['gender'] == 'Female') & (filler['in_top_15'] == True) & (filler['education'] == 'Bachelor')]
# Out:
# Empty DataFrame
# Columns: [state, title, race, gender, experience, education, in_top_15, yearsatcompany, basesalary, stockgrantvalue, bonus]
# Index: []

# %%
#when there is no filler data it returns an empty df
def find filler data ( user input) 
    if df is empty
        return sorry no data found
    else
        return filler data

# %%
#ca, data scientist, asian, bachelors, apple, 4, male

# %%
#change experience from numerical values to categorical
no = 0 years
little = 1 - 3
medium = 4 - 6
a lot = 6+

# %%
df.head()
# Out:
#      company              title  totalyearlycompensation  yearsofexperience  \
# 0     Google  Software Engineer                   400000                5.0
# 1  Microsoft  Software Engineer                   136000                3.0
# 2     Google  Software Engineer                   337000                6.0
# 3  Microsoft  Software Engineer                   222000                4.0
# 4      Blend  Software Engineer                   187000                5.0
#
#    yearsatcompany  basesalary  stockgrantvalue    bonus gender  \
# 0             5.0    210000.0         145000.0  45000.0   Male
# 1             2.0    124000.0           1000.0  11000.0   Male
# 2             6.0    177000.0         125000.0  36000.0   Male
# 3             4.0    164000.0          38000.0  20000.0   Male
# 4             0.0    165000.0          22000.0      0.0   Male
#
#    Masters_Degree  ...  Some_College  Race_Asian  Race_White  \
# 0               0  ...             0           1           0
# 1               0  ...             0           0           0
# 2               0  ...             0           1           0
# 3               1  ...             0           1           0
# 4               0  ...             0           0           1
#
#    Race_Two_Or_More  Race_Black  Race_Hispanic  state  in_top_15  education  \
# 0                 0           0              0     CA       True        PHD
# 1                 1           0              0     WA       True  Bachelors
# 2                 0           0              0     CA       True  Bachelors
# 3                 0           0              0     WA       True    Masters
# 4                 0           0              0     CA      False  Bachelors
#
#     race
# 0  Asian
# 1    Two
# 2  Asian
# 3  Asian
# 4  White
#
# [5 rows x 23 columns]

# %%
def convert(years):
    if years == 0:
        return 'NO EXPERIENCE'
    elif 1 <= years <= 3:
        return 'LITTLE EXPERIENCE'
    elif 4 <= years <= 6:
        return 'Medium Experienced'
    else:
        return 'Very Experienced'

# %%
df['experience'] = df['yearsofexperience'].apply(convert)

# %%
df.head()
# Out:
#      company              title  totalyearlycompensation  yearsofexperience  \
# 0     Google  Software Engineer                   400000                5.0
# 1  Microsoft  Software Engineer                   136000                3.0
# 2     Google  Software Engineer                   337000                6.0
# 3  Microsoft  Software Engineer                   222000                4.0
# 4      Blend  Software Engineer                   187000                5.0
#
#    yearsatcompany  basesalary  stockgrantvalue    bonus gender  \
# 0             5.0    210000.0         145000.0  45000.0   Male
# 1             2.0    124000.0           1000.0  11000.0   Male
# 2             6.0    177000.0         125000.0  36000.0   Male
# 3             4.0    164000.0          38000.0  20000.0   Male
# 4             0.0    165000.0          22000.0      0.0   Male
#
#    Masters_Degree  ...  Race_Asian  Race_White  Race_Two_Or_More  Race_Black  \
# 0               0  ...           1           0                 0           0
# 1               0  ...           0           0                 1           0
# 2               0  ...           1           0                 0           0
# 3               1  ...           1           0                 0           0
# 4               0  ...           0           1                 0           0
#
#    Race_Hispanic  state  in_top_15  education   race          experience
# 0              0     CA       True        PHD  Asian  Medium Experienced
# 1              0     WA       True  Bachelors    Two   LITTLE EXPERIENCE
# 2              0     CA       True  Bachelors  Asian  Medium Experienced
# 3              0     WA       True    Masters  Asian  Medium Experienced
# 4              0     CA      False  Bachelors  White  Medium Experienced
#
# [5 rows x 24 columns]

# %%
def prediction(fillter data):
    best ml model = whatever() - knn
    predict(filler)_data
    return prediction
