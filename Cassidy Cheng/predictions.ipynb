# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleaned_data')
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#      company              title  totalyearlycompensation  yearsofexperience  \
# 0     Google  Software Engineer                   400000                5.0
# 1  Microsoft  Software Engineer                   136000                3.0
# 2     Google  Software Engineer                   337000                6.0
# 3  Microsoft  Software Engineer                   222000                4.0
# 4      Blend  Software Engineer                   187000                5.0
#
#    yearsatcompany  basesalary  stockgrantvalue    bonus gender  \
# 0             5.0    210000.0         145000.0  45000.0   Male
# 1             2.0    124000.0           1000.0  11000.0   Male
# 2             6.0    177000.0         125000.0  36000.0   Male
# 3             4.0    164000.0          38000.0  20000.0   Male
# 4             0.0    165000.0          22000.0      0.0   Male
#
#    Masters_Degree  ...  Some_College  Race_Asian  Race_White  \
# 0               0  ...             0           1           0
# 1               0  ...             0           0           0
# 2               0  ...             0           1           0
# 3               1  ...             0           1           0
# 4               0  ...             0           0           1
#
#    Race_Two_Or_More  Race_Black  Race_Hispanic  state  in_top_15  education  \
# 0                 0           0              0     CA       True        PHD
# 1                 1           0              0     WA       True  Bachelors
# 2                 0           0              0     CA       True  Bachelors
# 3                 0           0              0     WA       True    Masters
# 4                 0           0              0     CA      False  Bachelors
#
#     race
# 0  Asian
# 1    Two
# 2  Asian
# 3  Asian
# 4  White
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['company', 'title', 'totalyearlycompensation', 'yearsofexperience',
#        'yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus', 'gender',
#        'Masters_Degree', 'Bachelors_Degree', 'Doctorate_Degree', 'Highschool',
#        'Some_College', 'Race_Asian', 'Race_White', 'Race_Two_Or_More',
#        'Race_Black', 'Race_Hispanic', 'state', 'in_top_15', 'education',
#        'race'],
#       dtype='object')

# %%
#state, title, race, education, company, gender, experience
df.drop(['company'], axis=1, inplace=True)

# %%
def convert(years):
    if years == 0:
        return 'NO EXPERIENCE'
    elif 1 <= years <= 3:
        return 'LITTLE EXPERIENCE'
    elif 4 <= years <= 6:
        return 'MEDIUM EXPERIENCE'
    else:
        return 'VERY EXPERIENCED'

# %%
df['experience'] = df['yearsofexperience'].apply(convert)

# %%
input = ['state', 'title', 'race', 'education', 'gender', 'experience', 'in_top_15']
filler = df.groupby(by = input)['yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus'].mean()
filler.reset_index(inplace=True)
filler
# Out:
# /tmp/ipykernel_3500/2292288465.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   filler = df.groupby(by = input)['yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus'].mean()
#      state                      title   race  education  gender  \
# 0       CA           Business Analyst  Asian  Bachelors  Female
# 1       CA           Business Analyst  Asian  Bachelors  Female
# 2       CA           Business Analyst  Asian  Bachelors  Female
# 3       CA           Business Analyst  Asian  Bachelors  Female
# 4       CA           Business Analyst  Asian  Bachelors  Female
# ...    ...                        ...    ...        ...     ...
# 3382    WA  Technical Program Manager  White    Masters    Male
# 3383    WA  Technical Program Manager  White    Masters    Male
# 3384    WA  Technical Program Manager  White        PHD    Male
# 3385    WA  Technical Program Manager  White       Some  Female
# 3386    WA  Technical Program Manager  White       Some    Male
#
#              experience  in_top_15  yearsatcompany     basesalary  \
# 0     LITTLE EXPERIENCE      False        0.800000   98000.000000
# 1     LITTLE EXPERIENCE       True        1.666667   87333.333333
# 2     MEDIUM EXPERIENCE      False        0.500000  130000.000000
# 3     MEDIUM EXPERIENCE       True        1.000000  140000.000000
# 4         NO EXPERIENCE       True        0.000000   79500.000000
# ...                 ...        ...             ...            ...
# 3382   VERY EXPERIENCED      False        8.428571  162571.428571
# 3383   VERY EXPERIENCED       True        5.142857  182571.428571
# 3384   VERY EXPERIENCED       True        7.000000  185000.000000
# 3385   VERY EXPERIENCED       True       16.000000  182000.000000
# 3386   VERY EXPERIENCED       True        2.000000  206000.000000
#
#       stockgrantvalue         bonus
# 0        10600.000000  10600.000000
# 1         1000.000000   8333.333333
# 2         5000.000000   5000.000000
# 3        31000.000000  21000.000000
# 4            0.000000   7000.000000
# ...               ...           ...
# 3382      5714.285714  16857.142857
# 3383     53785.714286  33857.142857
# 3384    232500.000000  20000.000000
# 3385     40000.000000  42000.000000
# 3386     36750.000000  35250.000000
#
# [3387 rows x 11 columns]

# %%
filler.reset_index(inplace=True)

# %%
filler[(filler['state'] == 'CA') & (filler['title'] == 'Business Analyst') & (filler['race'] == 'Asian') & (filler['gender'] == 'Female') & (filler['in_top_15'] == True) & (filler['education'] == 'PHD')]
# Out:
# Empty DataFrame
# Columns: [index, state, title, race, education, gender, experience, in_top_15, yearsatcompany, basesalary, stockgrantvalue, bonus]
# Index: []

# %%
#change experience from numerical to categorical
#no = 0 years
#little = 1-3
#medium = 4-6
#a lot = 6+

# %%
df.head()
# Out:
#                title  totalyearlycompensation  yearsofexperience  \
# 0  Software Engineer                   400000                5.0
# 1  Software Engineer                   136000                3.0
# 2  Software Engineer                   337000                6.0
# 3  Software Engineer                   222000                4.0
# 4  Software Engineer                   187000                5.0
#
#    yearsatcompany  basesalary  stockgrantvalue    bonus gender  \
# 0             5.0    210000.0         145000.0  45000.0   Male
# 1             2.0    124000.0           1000.0  11000.0   Male
# 2             6.0    177000.0         125000.0  36000.0   Male
# 3             4.0    164000.0          38000.0  20000.0   Male
# 4             0.0    165000.0          22000.0      0.0   Male
#
#    Masters_Degree  Bachelors_Degree  ...  Race_Asian  Race_White  \
# 0               0                 0  ...           1           0
# 1               0                 1  ...           0           0
# 2               0                 1  ...           1           0
# 3               1                 0  ...           1           0
# 4               0                 1  ...           0           1
#
#    Race_Two_Or_More  Race_Black  Race_Hispanic  state  in_top_15  education  \
# 0                 0           0              0     CA       True        PHD
# 1                 1           0              0     WA       True  Bachelors
# 2                 0           0              0     CA       True  Bachelors
# 3                 0           0              0     WA       True    Masters
# 4                 0           0              0     CA      False  Bachelors
#
#     race         experience
# 0  Asian  MEDIUM EXPERIENCE
# 1    Two  LITTLE EXPERIENCE
# 2  Asian  MEDIUM EXPERIENCE
# 3  Asian  MEDIUM EXPERIENCE
# 4  White  MEDIUM EXPERIENCE
#
# [5 rows x 23 columns]

# %%
#create groupby seven inputs & mean of outputs
input = ['state', 'title', 'race', 'gender', 'experience', 'education', 'in_top_15']
filler = df.groupby(by = input)['yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus'].mean()
filler.reset_index(inplace = True)
# Out:
# /tmp/ipykernel_3500/1973704127.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   filler = df.groupby(by = input)['yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus'].mean()

# %%
def findfillerdata(state, title, race, gender, experience, education, in_top_15):
    if state == '':
        return 'sorry no data found'
    elif title == '':
        return 'sorry no data found'
    elif race == '':
        return 'sorry no data found'
    elif gender == '':
        return 'sorry no data found'
    elif experience == '':
        return 'sorry no data found'
    elif education == '':
        return 'sorry no data found'
    elif in_top_15 == '':
        return 'sorry no data found'
    else:
        return filler

# %%
filler = filler.apply(lambda x: findfillerdata(x.state, x.title, x.race, x.gender, x.experience, x.education, x.in_top_15), axis=1)
filler.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [103], in <cell line: 1>()
# ----> 1 filler = filler.apply(lambda x: findfillerdata(x.state, x.title, x.race, x.gender, x.experience, x.education, x.in_top_15), axis=1)
#       2 filler.head()
#
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File ~/miniconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/apply.py:138, in Apply.__init__.<locals>.f(x)
#     137 def f(x):
# --> 138     return func(x, *args, **kwargs)
#
# TypeError: <lambda>() got an unexpected keyword argument 'axis'
